# %%
import pandas as pd
import numpy as np

df = pd.read_csv("data/dramas.csv")

# %%
df.head(10)
# Out:
#    Unnamed: 0                             name  \
# 0           0                           goblin
# 1           1        strong woman do bong soon
# 2           2  weightlifting fairy kim bok joo
# 3           3           descendants of the sun
# 4           4                                w
# 5           5  what's wrong with secretary kim
# 6           6         it's okay to not be okay
# 7           7             crash landing on you
# 8           8                boys over flowers
# 9           9                        the heirs
#
#                                              content  no_of_reviews  \
# 0  Kim Shin was once an unbeatable general in Gor...          464.0
# 1  Do Bong Soon is a petite, unemployed woman who...          345.0
# 2  Bok Joo is a weightlifter who is pursuing her ...          267.0
# 3  A love story that develops between a surgeon a...          270.0
# 4  Oh Sung Moo, the father of cardiothoracic surg...          285.0
# ...

# %%
df_users = pd.read_csv("data/users.csv")

# %%
df_users.head(10)
# Out:
#    user_id  gender        location  \
# 0  U000001  Female       Singapore
# 1  U000002  Female   United States
# 2  U000003  Female   United States
# 3  U000004  Female          Canada
# 4  U000005  Female           Italy
# 5  U000006    Male  United Kingdom
# 6  U000007  Female     Philippines
# 7  U000008  Female   United States
# 8  U000009  Female   United States
# 9  U000010  Female     Philippines
#
#                                   user_watch_history preferred_genre  \
# 0                             ["chicago typewriter"]         Mystery
# 1                    ["under the power", "memorist"]         Mystery
# 2  ["come and hug me", "six flying dragons", "moo...         Fantasy
# 3  ["the new employee", "oh! my emperor season 2"...          Comedy
# 4  ["birth of a beauty", "untouchable", "legend o...          Comedy
# 5  ["behind every star", "my girlfriend", "negoti...            Life
# 6  ["what's wrong with secretary kim", "stranger ...           Youth
# ...
